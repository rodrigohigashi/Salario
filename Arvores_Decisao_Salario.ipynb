# %% [markdown]
# # Árvores de Decisão: Regressão

# %% [markdown]
# ## Importação das bibliotecas

# %%
# Pacotes de preparação dos dados
import pandas as pd
import numpy as np

# Pacotes gráficos
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
from dtreeviz.trees import dtreeviz

# Pacotes de modelagem
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# Módulo de Análise Exploratória
import aed

# %% [markdown]
# ## Importação da base de dados

# %%
df_rh = pd.read_csv('base_funcionarios_v4.csv', 
                    sep=',',
                    index_col=0)
df_rh.sample(n=5)
# Out:
#     Salario  Anos_Educ_Superior  Tempo_Empresa  Tempo_de_Carreira
# 44   6235.4                   4              6           6.578993  \
# 32   6882.9                   6              9          17.658821
# 42   8521.6                   8              6          17.720932
# 23  12118.1                  10             22          37.366990
# 37   4629.1                   2              1           6.525988
#
#    Possui_Skill_Dados
# 44                Não
# 32                Não
# 42                Sim
# 23                Sim
# 37                Não

# %% [markdown]
# ## Preparação dos Dados

# %% [markdown]
# ### Missing Values

# %%
df_rh.isnull().sum()
# Out:
# Salario               0
# Anos_Educ_Superior    0
# Tempo_Empresa         0
# Tempo_de_Carreira     0
# Possui_Skill_Dados    0
# dtype: int64

# %% [markdown]
# ### Duplicações

# %%
df_rh.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Tipos de Variáveis

# %%
df_rh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 46 entries, 0 to 45
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Salario             46 non-null     float64
#  1   Anos_Educ_Superior  46 non-null     int64
#  2   Tempo_Empresa       46 non-null     int64
#  3   Tempo_de_Carreira   46 non-null     float64
#  4   Possui_Skill_Dados  46 non-null     object
# dtypes: float64(2), int64(2), object(1)
# memory usage: 2.2+ KB

# %% [markdown]
# ## Análise Exploratória dos Dados

# %% [markdown]
# ### Dispersão por Classe

# %%
import matplotlib
matplotlib.use('module://ipykernel.pylab.backend_inline')

sns.pairplot(df_rh, kind='reg');

# %% [markdown]
# ### Relatórios Pandas Profiling e SweetViz

# %%
perfil_pp, perfil_sv = aed.gera_relatorios_aed(df=df_rh,
                                               target_feat='Salario')
# Out:
# c:\Users\rocki\OneDrive\Documentos\GitHub\Turnover\venv\lib\site-packages\ydata_profiling\profile_report.py:358: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# Summarize dataset: 100%|██████████| 30/30 [00:01<00:00, 19.08it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:01<00:00,  1.32s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.67it/s]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 246.93it/s]
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:00 -> (00:00 left)
# Report base_aed_sv.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# ## Desenvolvimento do Modelo: Árvores de Decisão
# Neste exemplo utilizaremos a biblioteca Scikit Learn, uma das mais utilizadas para o desenvolvimento de modelos de *Machine Learning*.

# %% [markdown]
# ### Definição do *Target* e das *Features*

# %%
# Criação das variáveis dummies
df_rh_modelo = pd.get_dummies(df_rh)
df_rh_modelo.head()
# Out:
#    Salario  Anos_Educ_Superior  Tempo_Empresa  Tempo_de_Carreira
# 0   5517.4                   3              3           9.777079  \
# 1   6399.9                   4              6           3.765998
# 2   6206.7                   6              3           7.926264
# 3   6060.6                   4              5           2.233497
# 4   6122.7                   2              9          26.821842
#
#    Possui_Skill_Dados_Não  Possui_Skill_Dados_Sim
# 0                    True                   False
# 1                    True                   False
# 2                    True                   False
# 3                    True                   False
# 4                    True                   False

# %%
# Target (variável resposta)
y = df_rh_modelo['Salario']

# Features (variáveis explicativas)
x = df_rh_modelo.drop('Salario', axis = 1)

# %% [markdown]
# ### Treinamento da Árvore de Decisão

# %%
modelo_salario = DecisionTreeRegressor(max_depth=2, 
                                       random_state=42)
modelo_salario.fit(x, y)
# Out:
# DecisionTreeRegressor(max_depth=2, random_state=42)

# %% [markdown]
# ### Avaliação do modelo treinado

# %% [markdown]
# #### Interpretação do Modelo

# %%
sns.reset_defaults()
# %matplotlib inline
fig = plt.figure(figsize=(15,10))
features = list(x.columns)
tree.plot_tree(modelo_salario,
               feature_names=features,
               filled=True);
plt.title("Estimativa de Salários\n Utilizando Árvores de Decisão");

# %%
viz = dtreeviz(tree_model=modelo_salario, 
               x_data=x, y_data=y, 
               target_name='Salario',
               feature_names=features,
               scale=2.0)
viz
# Out:
# c:\Users\rocki\OneDrive\Documentos\GitHub\Turnover\venv\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %% [markdown]
# #### Desempenho do Modelo

# %%
# Cálculo do desempenho do modelo: R²
r2 = r2_score(y, modelo_salario.predict(x))

n = len(y)
p = x.shape[1]
r2_adjusted = 1 - (1 - r2) * (n - 1)/(n - p - 1)

print(f"R²: {r2:.4f}")
print(f"R² Ajustado: {r2_adjusted:.4f}")
# Out:
# R²: 0.8771
# R² Ajustado: 0.8618

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size = 0.3, random_state = 101)

# %%
predictions = modelo_salario.predict(X_test)

# %%
# Calculating MAE
mae = mean_absolute_error(Y_test, predictions)
print(f"MAE: {mae}")

# Calculating MSE
mse = mean_squared_error(Y_test, predictions)
print(f"MSE: {mse}")

# Calculating RMSE
rmse = np.sqrt(mse)
print(f"RMSE: {rmse}")

# Calculating MAPE
mape = np.mean(np.abs((Y_test - predictions) / Y_test)) * 100
print(f"MAPE: {mape}")
# Out:
# MAE: 554.4632467532475
# MSE: 453022.9350110987
# RMSE: 673.0697846517096
# MAPE: 9.117093301301244
